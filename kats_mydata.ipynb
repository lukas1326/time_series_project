# %%
import pickle
import pandas as pd
import numpy
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %%
import warnings
warnings.filterwarnings('ignore')

from kats.consts import TimeSeriesData
# if error "Cannot uninstall 'llvmlite'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall"
# delete the file C:\Users\olga\anaconda3\Lib\site-packages\llvmlite-0.23.1-py3.6.egg-info


#https://github.com/facebookresearch/Kats/blob/master/tutorials/kats_101_basics.ipynb

# %%
with open('date_for_ts.pickle','rb') as f:
    df = pickle.load(f)

# %%
df.head()
# Out:
#         time
# 0 2017-10-15
# 1 2017-10-07
# 2 2017-08-20
# 3 2017-03-31
# 4 2017-03-05

# %%
df = df[df.time.dt.year>2017]
df
# Out:
#            time
# 41   2018-01-24
# 42   2018-01-26
# 43   2018-01-09
# 46   2018-01-18
# 49   2018-01-27
# 50   2018-02-01
# 51   2018-01-18
# 52   2018-03-02
# 53   2018-02-12
# 54   2018-02-25
# 55   2018-02-01
# 56   2018-03-16
# 57   2018-03-25
# 58   2018-02-21
# 59   2018-03-30
# 60   2018-03-23
# 61   2018-03-01
# 62   2018-04-06
# 63   2018-03-21
# 64   2018-03-23
# 65   2018-04-06
# 66   2018-04-27
# 67   2018-04-08
# 68   2018-05-27
# 69   2018-05-18
# 70   2018-05-23
# 71   2018-06-28
# 72   2018-07-03
# 73   2018-08-10
# 74   2018-08-12
# 75   2018-08-22
# 76   2018-08-16
# 77   2018-10-23
# 78   2018-10-31
# 79   2018-11-11
# 80   2018-10-08
# 81   2018-11-30
# 82   2018-11-23
# 83   2018-11-22
# 84   2018-11-25
# 85   2018-11-30
# 86   2018-11-23
# 87   2018-11-15
# 88   2018-12-30
# 89   2019-01-11
# 90   2018-11-28
# 91   2018-12-09
# 92   2019-01-21
# 93   2018-12-26
# 94   2019-01-19
# 95   2019-01-18
# 96   2018-12-30
# 97   2018-12-14
# 98   2019-01-01
# ...

# %%
ts1 = df.resample('D',on='time').count()
ts1.columns = ['value']

# %%
ts2 = TimeSeriesData(ts1.reset_index())

# %%
#ts2 = ts2[0:-2]

# %%
ts2.is_empty()
# Out:
# False

# %%
ts2.is_univariate()
# Out:
# True

# %%
# import the param and model classes for Prophet model
from kats.models.prophet import ProphetModel, ProphetParams

# create a model param instance
params = ProphetParams(seasonality_mode='additive',weekly_seasonality=True) # additive mode gives worse results

# create a prophet model instance
m = ProphetModel(ts2, params)

# fit model simply by calling m.fit()
m.fit()

# make prediction for next 30 month
fcst = m.predict(steps=12, freq="W")
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
fcst
# Out:
#          time       fcst  fcst_lower  fcst_upper
# 0  2021-03-28  48.464708   41.066517   56.151252
# 1  2021-04-04  48.593165   41.749839   56.094414
# 2  2021-04-11  47.841123   40.505436   55.749562
# 3  2021-04-18  46.670558   39.508066   54.354883
# 4  2021-04-25  46.098918   38.744955   53.638496
# 5  2021-05-02  46.887490   39.383717   54.488947
# 6  2021-05-09  48.727892   41.741290   56.061772
# 7  2021-05-16  50.353271   43.343604   57.790968
# 8  2021-05-23  50.576833   43.204388   58.029411
# 9  2021-05-30  49.277024   42.024946   56.704728
# 10 2021-06-06  47.445225   39.964015   54.705876
# 11 2021-06-13  46.398832   38.773057   53.864169

# %%
m.plot()

# %%
from kats.detectors.outlier import OutlierDetector

ts_outlierDetection = OutlierDetector(ts2, 'additive') # call OutlierDetector
ts_outlierDetection.detector() # apply OutlierDetector

# %%
ts_outlierDetection.outliers[0]
# Out:
# []

# %%
from kats.consts import TimeSeriesData, TimeSeriesIterator
from kats.detectors.cusum_detection import CUSUMDetector

# %%
detector = CUSUMDetector(ts2)

# %%
# run detector
change_points = detector.detector(change_directions=["increase"])

# %%
change_points
# Out:
# []

# %%
# plot the results
plt.xticks(rotation=45)
detector.plot(change_points)
plt.show()
# Out:
# WARNING:root:No change points detected!

# %%
# import param and model from `kats.models.theta`
from kats.models.theta import ThetaModel, ThetaParams

# create ThetaParam with specifying seasonality param value
params = ThetaParams(m=12)

# create ThetaModel with given data and parameter class
m = ThetaModel(data=ts2, params=params)

# call fit method to fit model
m.fit()

# call predict method to predict the next 30 steps
res = m.predict(steps=30, alpha=0.2)

# visualize the results
m.plot()

# %%
res
# Out:
#           time       fcst  fcst_lower  fcst_upper
# 168 2021-03-28  44.409602   35.910667   52.908536
# 169 2021-04-04  44.447423   35.763609   53.131237
# 170 2021-04-11  44.485244   35.620406   53.350082
# 171 2021-04-18  44.523066   35.480827   53.565304
# 172 2021-04-25  44.560887   35.344661   53.777113
# 173 2021-05-02  44.598708   35.211720   53.985696
# 174 2021-05-09  44.636529   35.081830   54.191229
# 175 2021-05-16  44.674350   34.954833   54.393868
# 176 2021-05-23  44.712172   34.830586   54.593758
# 177 2021-05-30  44.749993   34.708953   54.791033
# 178 2021-06-06  44.787814   34.589814   54.985814
# 179 2021-06-13  44.825635   34.473054   55.178217
# 180 2021-06-20  44.863457   34.358569   55.368345
# 181 2021-06-27  44.901278   34.246260   55.556296
# 182 2021-07-04  44.939099   34.136038   55.742161
# 183 2021-07-11  44.976920   34.027817   55.926024
# 184 2021-07-18  45.014742   33.921518   56.107965
# 185 2021-07-25  45.052563   33.817068   56.288057
# ...

# %%
# Initiate feature extraction class
from kats.tsfeatures.tsfeatures import TsFeatures
tsFeatures = TsFeatures()

# %%
features_ts2 = TsFeatures().transform(ts2)
features_ts2
# Out:
# C:\Users\olga\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1906: InterpolationWarning:
#
# The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
# {'length': 168,
#  'mean': 39.01190476190476,
#  'var': 64.16652494331063,
#  'entropy': 0.7869597133781038,
#  'lumpiness': 53.783499581966005,
#  'stability': 25.719374453509168,
#  'flat_spots': 2,
#  'hurst': 0.10024994162249375,
#  'std1st_der': 4.3826251578032,
#  'crossing_points': 67,
#  'binarize_mean': 0.42857142857142855,
#  'unitroot_kpss': 0.3741011420629137,
#  'heterogeneity': 50.80040631700347,
#  'histogram_mode': 35.6,
#  'linearity': 0.2097223406130416,
#  'trend_strength': 0.653858287102747,
#  'seasonality_strength': 0.3810885843869909,
#  'spikiness': 0.018163628844894156,
#  'peak': 5,
#  'trough': 6,
#  'level_shift_idx': 34,
#  'level_shift_size': 1.3000000000000043,
#  'y_acf1': 0.43153861998904286,
# ...

# %%
from kats.models.sarima import SARIMAModel, SARIMAParams
warnings.simplefilter(action='ignore')

# create SARIMA param class
params = SARIMAParams(
    p = 2, 
    d=1, 
    q=1, 
    trend = 'ct', 
    seasonal_order=(1,0,1,12)
    )

# initiate SARIMA model
m = SARIMAModel(data=ts2, params=params)

# fit SARIMA model
m.fit()

# generate forecast values
fcst = m.predict(
    steps=30, 
    freq="MS"
    )

# make plot to visualize
m.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-250-0a050a810385> in <module>
#      18
#      19 # generate forecast values
# ---> 20 fcst = m.predict(
#      21     steps=30,
#      22     freq="MS"
#
# ~\anaconda3\lib\site-packages\kats\models\sarima.py in predict(self, steps, include_history, alpha, **kwargs)
#     334             self.fcst_df.loc[0:k, ["fcst", "fcst_lower", "fcst_upper"]] = np.nan
#     335         else:
# --> 336             self.fcst_df = pd.DataFrame(
#     337                 {
#     338                     "time": self.dates,
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
# ...

# %%
from kats.models.holtwinters import HoltWintersParams, HoltWintersModel
warnings.simplefilter(action='ignore')


params = HoltWintersParams(
            trend="add",
            #damped=False,
            seasonal="mul",
            seasonal_periods=12,
        )
m = HoltWintersModel(
    data=ts2, 
    params=params)

m.fit()
fcst = m.predict(steps=30, alpha = 0.1)
m.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-251-9b4f2c0185f4> in <module>
#      13     params=params)
#      14
# ---> 15 m.fit()
#      16 fcst = m.predict(steps=30, alpha = 0.1)
#      17 m.plot()
#
# ~\anaconda3\lib\site-packages\kats\models\holtwinters.py in fit(self, **kwargs)
#     116
#     117         logging.debug("Call fit() with parameters:{kwargs}".format(kwargs=kwargs))
# --> 118         holtwinters = HoltWinters(
#     119             self.data.value,
#     120             trend=self.params.trend,
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ...

# %%
from kats.detectors.bocpd import BOCPDetector, BOCPDModelType, TrendChangeParameters

# Initialize the detector
detector = BOCPDetector(ts2)


changepoints = detector.detector(
    model=BOCPDModelType.NORMAL_KNOWN_MODEL # this is the default choice
)

# Plot the data
plt.xticks(rotation=45)
detector.plot(changepoints)
plt.show()
# Out:
# WARNING:root:No change points detected!

# %%
changepoints
# Out:
# [(TimeSeriesChangePoint(start_time: 2020-04-26T00:00:00.000000000, end_time: 2020-04-26T00:00:00.000000000, confidence: 0.6762747703188958),
#   <kats.detectors.bocpd.BOCPDMetadata at 0x22668b8a880>),
#  (TimeSeriesChangePoint(start_time: 2020-12-06T00:00:00.000000000, end_time: 2020-12-06T00:00:00.000000000, confidence: 0.6357508677764271),
#   <kats.detectors.bocpd.BOCPDMetadata at 0x22668b8a6d0>)]

# %%
from kats.detectors.robust_stat_detection import RobustStatDetector

detector = RobustStatDetector(ts2)
change_points = detector.detector()

plt.xticks(rotation=45)
detector.plot(change_points)
plt.show()

# %%
change_points
# Out:
# [(TimeSeriesChangePoint(start_time: 2018-06-13T00:00:00.000000000, end_time: 2018-06-13T00:00:00.000000000, confidence: 0.9921783596695286),
#   <kats.detectors.robust_stat_detection.RobustStatMetadata at 0x22668e58880>),
#  (TimeSeriesChangePoint(start_time: 2018-07-05T00:00:00.000000000, end_time: 2018-07-05T00:00:00.000000000, confidence: 0.9976316017495921),
#   <kats.detectors.robust_stat_detection.RobustStatMetadata at 0x226687bb3d0>),
#  (TimeSeriesChangePoint(start_time: 2018-08-16T00:00:00.000000000, end_time: 2018-08-16T00:00:00.000000000, confidence: 0.99760127817121),
#   <kats.detectors.robust_stat_detection.RobustStatMetadata at 0x2266addf0d0>),
#  (TimeSeriesChangePoint(start_time: 2018-08-26T00:00:00.000000000, end_time: 2018-08-26T00:00:00.000000000, confidence: 0.9921783596695286),
#   <kats.detectors.robust_stat_detection.RobustStatMetadata at 0x2266addf670>),
# ...

# %%
detector = RobustStatDetector(ts2)
changepoints = detector.detector(p_value_cutoff = 5e-3, comparison_window=3)

# plot the results
plt.xticks(rotation=45)
detector.plot(changepoints)
plt.show()

# %%
changepoints
# Out:
# [(TimeSeriesChangePoint(start_time: 2019-07-21T00:00:00.000000000, end_time: 2019-07-21T00:00:00.000000000, confidence: 0.9954474554630023),
#   <kats.detectors.robust_stat_detection.RobustStatMetadata at 0x22669b8cb20>),
#  (TimeSeriesChangePoint(start_time: 2020-02-16T00:00:00.000000000, end_time: 2020-02-16T00:00:00.000000000, confidence: 0.9973109804993813),
#   <kats.detectors.robust_stat_detection.RobustStatMetadata at 0x22669b8ca30>)]

# %%
from kats.detectors.trend_mk import MKDetector

detector = MKDetector(data=ts2, threshold=.8)
# run detector
detected_time_points = detector.detector(direction='down', window_size=30, freq='weekly')
# plot the results
detector.plot(detected_time_points)

# %%
# Out:
# [(TimeSeriesChangePoint(start_time: 2019-04-17 00:00:00, end_time: 2019-04-17 00:00:00, confidence: 0.9999999997866456),
#   <kats.detectors.trend_mk.MKMetadata at 0x2266b534760>),
#  (TimeSeriesChangePoint(start_time: 2019-04-18 00:00:00, end_time: 2019-04-18 00:00:00, confidence: 0.9999999999845819),
#   <kats.detectors.trend_mk.MKMetadata at 0x2266ade0dc0>),
#  (TimeSeriesChangePoint(start_time: 2019-04-19 00:00:00, end_time: 2019-04-19 00:00:00, confidence: 0.9999999999879483),
#   <kats.detectors.trend_mk.MKMetadata at 0x2266b17ee50>),
#  (TimeSeriesChangePoint(start_time: 2019-04-20 00:00:00, end_time: 2019-04-20 00:00:00, confidence: 0.9999999999679572),
#   <kats.detectors.trend_mk.MKMetadata at 0x226696a79d0>),
#  (TimeSeriesChangePoint(start_time: 2019-04-21 00:00:00, end_time: 2019-04-21 00:00:00, confidence: 0.9999999997866456),
#   <kats.detectors.trend_mk.MKMetadata at 0x226696a7c10>),
# ...
